# %%
from notebook_environment import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
rpkm__gene_x_ccle_cellline = gct.read_gct(
    '../data/rpkm__gene_x_ccle_cellline.gct')
print(rpkm__gene_x_ccle_cellline.shape)

kras_relevant_genes = pd.read_table(
    '../results/kras_relevant_genes.txt', header=None, squeeze=True)
print(kras_relevant_genes.shape)

rpkm__kras_relevant_gene_x_ccle_cellline = rpkm__gene_x_ccle_cellline.loc[
    kras_relevant_genes, :]
print(rpkm__kras_relevant_gene_x_ccle_cellline.shape)
# Out:
# (48642, 750)
# (1000,)
# (1000, 750)

# %%
nmfs, nmf_ccs, cccs = oncogps.define_components(
    rpkm__kras_relevant_gene_x_ccle_cellline,
    range(2, 11),
    '../results',
    a_matrix_normalization_method='rank',
    a_matrix_post_normalization_scale_factor=10000,
    algorithm='ls',
    n_clusterings=30,
    n_jobs=9,
    random_seed=6137)
# Out:
# Dropping axis-0 slices with at most 1 unique objects ...
# Dropping axis-1 slices with at most 1 unique objects ...
# /home/k/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# NMF with k=2 ...
# 	(k=2) 0/30 ...
# NMF with k=3 ...
# 	(k=3) 0/30 ...
# NMF with k=4 ...
# 	(k=4) 0/30 ...
# NMF with k=5 ...
# 	(k=5) 0/30 ...
# NMF with k=6 ...
# NMF with k=7 ...
# 	(k=6) 0/30 ...
# 	(k=7) 0/30 ...
# NMF with k=8 ...
# NMF with k=9 ...
# 	(k=8) 0/30 ...
# NMF with k=10 ...
# 	(k=9) 0/30 ...
# 	(k=10) 0/30 ...
# 	(k=2) 1/30 ...
# 	(k=3) 1/30 ...
# 	(k=4) 1/30 ...
# 	(k=9) 1/30 ...
# 	(k=5) 1/30 ...
# 	(k=6) 1/30 ...
# 	(k=7) 1/30 ...
# 	(k=8) 1/30 ...
# 	(k=2) 2/30 ...
# 	(k=10) 1/30 ...
# 	(k=3) 2/30 ...
# 	(k=4) 2/30 ...
# 	(k=9) 2/30 ...
# 	(k=5) 2/30 ...
# 	(k=2) 3/30 ...
# 	(k=6) 2/30 ...
# 	(k=7) 2/30 ...
# 	(k=3) 3/30 ...
# 	(k=8) 2/30 ...
# 	(k=2) 4/30 ...
# 	(k=4) 3/30 ...
# 	(k=10) 2/30 ...
# 	(k=9) 3/30 ...
# 	(k=2) 5/30 ...
# 	(k=5) 3/30 ...
# 	(k=3) 4/30 ...
# 	(k=6) 3/30 ...
# 	(k=2) 6/30 ...
# 	(k=7) 3/30 ...
# 	(k=4) 4/30 ...
# 	(k=8) 3/30 ...
# 	(k=2) 7/30 ...
# 	(k=9) 4/30 ...
# 	(k=5) 4/30 ...
# 	(k=3) 5/30 ...
# 	(k=10) 3/30 ...
# 	(k=2) 8/30 ...
# 	(k=6) 4/30 ...
# 	(k=4) 5/30 ...
# 	(k=7) 4/30 ...
# 	(k=2) 9/30 ...
# 	(k=9) 5/30 ...
# 	(k=8) 4/30 ...
# 	(k=3) 6/30 ...
# 	(k=5) 5/30 ...
# 	(k=2) 10/30 ...
# 	(k=6) 5/30 ...
# 	(k=10) 4/30 ...
# 	(k=4) 6/30 ...
# 	(k=3) 7/30 ...
...
# Computing clustering distances (1 - coclusterings) ...
# Hierarchical cluster clustering distances and computing ccc ...
# ../tools/repositories/oncogps/oncogps/clustering/clustering/consensus_cluster.py:75: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   hc = linkage(distances, method=method)
# 	(k=10) 22/30 ...
# 	(k=6) 28/30 ...
# 	(k=9) 26/30 ...
# 	(k=8) 25/30 ...
# 	(k=7) 27/30 ...
# 	(k=6) 29/30 ...
# 	(k=10) 23/30 ...
# 	(k=9) 27/30 ...
# 	(k=8) 26/30 ...
# 	(k=7) 28/30 ...
# Counting coclusterings ...
# Computing clustering distances (1 - coclusterings) ...
# Hierarchical cluster clustering distances and computing ccc ...
# ../tools/repositories/oncogps/oncogps/clustering/clustering/consensus_cluster.py:75: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   hc = linkage(distances, method=method)
# 	(k=9) 28/30 ...
# 	(k=10) 24/30 ...
# 	(k=8) 27/30 ...
# 	(k=7) 29/30 ...
# Counting coclusterings ...
# 	(k=9) 29/30 ...
# 	(k=8) 28/30 ...
# 	(k=10) 25/30 ...
# Computing clustering distances (1 - coclusterings) ...
# Hierarchical cluster clustering distances and computing ccc ...
# ../tools/repositories/oncogps/oncogps/clustering/clustering/consensus_cluster.py:75: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   hc = linkage(distances, method=method)
# 	(k=8) 29/30 ...
# Counting coclusterings ...
# Computing clustering distances (1 - coclusterings) ...
# Hierarchical cluster clustering distances and computing ccc ...
# ../tools/repositories/oncogps/oncogps/clustering/clustering/consensus_cluster.py:75: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   hc = linkage(distances, method=method)
# 	(k=10) 26/30 ...
# Counting coclusterings ...
# Computing clustering distances (1 - coclusterings) ...
# Hierarchical cluster clustering distances and computing ccc ...
# ../tools/repositories/oncogps/oncogps/clustering/clustering/consensus_cluster.py:75: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   hc = linkage(distances, method=method)
# 	(k=10) 27/30 ...
# 	(k=10) 28/30 ...
# 	(k=10) 29/30 ...
# Counting coclusterings ...
# Computing clustering distances (1 - coclusterings) ...
# Hierarchical cluster clustering distances and computing ccc ...
# ../tools/repositories/oncogps/oncogps/clustering/clustering/consensus_cluster.py:75: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   hc = linkage(distances, method=method)
# /home/k/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
w_matrix = gct.read_gct('../results/nmf_k9_w.gct')
h_matrix = gct.read_gct('../results/nmf_k9_h.gct')

# %%
# Re-label components to have same names as in the paper
indices = [
    'C1',
    'C3',
    'C9',
    'C8',
    'C6',
    'C7',
    'C5',
    'C2',
    'C4',
]

w_matrix.columns = indices
h_matrix.index = indices

gct.write_gct(w_matrix, '../results/nmf_k9_w.gct')
gct.write_gct(h_matrix, '../results/nmf_k9_h.gct')

# %%
plot_nmf.plot_nmf(w_matrix, h_matrix, figure_size=(16, 16))
# Out:
# /home/k/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
comparison_panel.make_comparison_panel(
    h_matrix,
    h_matrix,
    axis=1,
    figure_size=(16, 16),
    a2d0_name='Component',
    a2d1_name='Component')
# Out:
# Applying (1/9) ...
# Applying (2/9) ...
# Applying (3/9) ...
# Applying (4/9) ...
# Applying (5/9) ...
# Applying (6/9) ...
# Applying (7/9) ...
# Applying (8/9) ...
# Applying (9/9) ...
# <class 'numpy.ndarray'>
# /home/k/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
#           C1        C3        C9        C8        C6        C7        C5  \
# C1  0.993211  0.618360  0.619073 -0.482277 -0.684898 -0.375985 -0.447607
# C3  0.618360  0.990896 -0.431972 -0.481347 -0.417796 -0.366643 -0.444453
# C9  0.619073 -0.431972  0.992197 -0.454180 -0.488886  0.339779 -0.468196
# C8 -0.482277 -0.481347 -0.454180  0.985058 -0.395221 -0.513312 -0.382879
# C6 -0.684898 -0.417796 -0.488886 -0.395221  0.986100 -0.308961 -0.355839
# C7 -0.375985 -0.366643  0.339779 -0.513312 -0.308961  0.991514  0.343476
# C5 -0.447607 -0.444453 -0.468196 -0.382879 -0.355839  0.343476  0.993971
# C2 -0.474957 -0.376321 -0.388273  0.496671  0.344208 -0.260692  0.347134
# C4 -0.785337 -0.547097 -0.472228 -0.465809  0.581471  0.473975 -0.376030
#
#           C2        C4
# C1 -0.474957 -0.785337
# C3 -0.376321 -0.547097
# C9 -0.388273 -0.472228
# C8  0.496671 -0.465809
# C6  0.344208  0.581471
# C7 -0.260692  0.473975
# C5  0.347134 -0.376030
# C2  0.993189 -0.445775
# C4 -0.445775  0.992467
