# %%
from notebook_environment import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# Added '../tools/' to the path.

# %% [markdown]
# # Read H matrix

# %%
h_matrix = pd.read_table('../results/nmf_k9_h.txt', index_col=0)

# %% [markdown]
# # Make match panels

# %%
features = [
    [
        'Mutation',
        ccal.read_gct('../data/mutation__gene_x_ccle_cellline.gct'),
        'high',
        'binary',
    ],
    [
        'Gene Expression',
        ccal.read_gct('../data/rpkm__gene_x_ccle_cellline.gct'),
        'high',
        'continuous',
    ],
    [
        'Gene Set',
        ccal.read_gct('../data/gene_set__gene_set_x_ccle_cellline.gct'),
        'high',
        'continuous',
    ],
    [
        'Regulator Gene Set',
        ccal.read_gct('../data/regulator__gene_set_x_ccle_cellline.gct'),
        'high',
        'continuous',
    ],
    [
        'Protein Expression',
        ccal.read_gct('../data/rppa__protein_x_ccle_cellline.gct'),
        'high',
        'continuous',
    ],
    [
        'Gene Dependency (Achilles)',
        ccal.read_gct('../data/achilles__gene_x_ccle_cellline.gct'),
        'low',
        'continuous',
    ],
    [
        'Drug Sensitivity (CTD^2)',
        ccal.read_gct('../data/ctd2__compound_x_ccle_cellline.gct'),
        'low',
        'continuous',
    ],
]

# %%
for i, component in h_matrix.iterrows():

    print('v' * 80)
    print(i)
    print('=' * 80)

    for features_name, features_, emphasis, data_type in features:

        print('Annotating with {} (emphasis={} & data_type={})'.format(
            features_name, emphasis, data_type))
        
        ccal.make_match_panel(
            component,
            features_,
            n_jobs=28,
            n_features=20,
            n_samplings=3,
            n_permutations=3,
            scores_ascending=[True, False][emphasis == 'high'],
            features_type=data_type,
            title=features_name,
            file_path_prefix='../results/match_{}_and_{}'.format(
                i, features_name))

        mpl.pyplot.show()

    print('^' * 80)
# Out:
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# C1
# ================================================================================
# Annotating with Mutation (emphasis=high & data_type=binary)
# Computing match score with <function compute_information_coefficient at 0x7f3ef4dd2488> (28 process) ...
# Computing MoEs with 3 samplings ...
# Computing p-values and FDRs with 3 permutations ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-6e6c30834fa0> in <module>()
#      21             title=features_name,
#      22             file_path_prefix='../results/match_{}_and_{}'.format(
# ---> 23                 i, features_name))
#      24
#      25         mpl.pyplot.show()
#
# ~/Jumis/onco_gps_paper_analysis/tools/ccal/ccal/match/match/make_match_panel.py in make_match_panel(target, features, target_ascending, n_jobs, scores_ascending, n_features, max_n_features, n_samplings, n_permutations, random_seed, figure_size, title, target_type, features_type, max_std, target_annotation_kwargs, plot_sample_names, file_path_prefix, dpi)
#     130                      annotations, figure_size, None, None, target_type,
#     131                      features_type, title, target_annotation_kwargs,
# --> 132                      plot_sample_names, file_path_plot, dpi)
#     133
#     134     return scores
#
# ~/Jumis/onco_gps_paper_analysis/tools/ccal/ccal/match/match/plot_match_panel.py in plot_match_panel(target, target_int_to_o, features, max_std, annotations, figure_size, target_ax, features_ax, target_type, features_type, title, target_annotation_kwargs, plot_sample_names, file_path, dpi)
#     113         xticklabels=False,
#     114         yticklabels=[target.name],
# --> 115         cbar=False)
#     116
#     117     # Decorate target heatmap
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526     if square:
#     527         ax.set_aspect("equal")
# --> 528     plotter.plot(ax, cbar_ax, kwargs)
#     529     return ax
#     530
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
#     313
#     314         # Possibly rotate them if they overlap
# --> 315         ax.figure.draw(ax.figure.canvas.get_renderer())
#     316         if axis_ticklabels_overlap(xtl):
#     317             plt.setp(xtl, rotation="vertical")
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     474
#     475         if need_new_renderer:
# --> 476             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     477             self._lastKey = key
#     478         elif cleared:
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      91         self.height = height
#      92         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 1152x80784 pixels is too large. It must be less than 2^16 in each direction.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     120
#     121     bytes_io = BytesIO()
# --> 122     fig.canvas.print_figure(bytes_io, **kw)
#     123     data = bytes_io.getvalue()
#     124     if fmt == 'svg':
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2198                     orientation=orientation,
#    2199                     dryrun=True,
# -> 2200                     **kwargs)
#    2201                 renderer = self.figure._cachedRenderer
#    2202                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     457         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     458
# --> 459         self.renderer = self.get_renderer(cleared=True)
#     460         # acquire a lock on the shared font cache
#     461         RendererAgg.lock.acquire()
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     474
#     475         if need_new_renderer:
# --> 476             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     477             self._lastKey = key
#     478         elif cleared:
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      91         self.height = height
#      92         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 93         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      94         self._filter_renderers = []
#      95
#
# ValueError: Image size of 1152x80784 pixels is too large. It must be less than 2^16 in each direction.

# %% [markdown]
# # Make summary match panels

# %%
# Select component
component = 'C3'
target = h_matrix.loc[component, :]
target.name = 'KRAS Component {}'.format(component)

# Select features
features = [
    [
        'Mutation',
        gct.read_gct('../data/mutation__gene_x_ccle_cellline.gct'),
        'high',
        'binary',
        '../results/match_{}_and_Mutation.match.txt'.format(component),
        [
            'KRAS_MUT',
            'APC_MUT',
            'CTNNB1_MUT',
        ],
        [
            'KRAS',
            'APC',
            'CTNNB1',
        ],
    ],
    [
        'Gene Set',
        gct.read_gct('../data/gene_set__gene_set_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Gene Set.match.txt'.format(component),
        [
            'SINGH_KRAS_DEPENDENCY_SIGNATURE_',
        ],
        [
            'KRAS Dependency',
        ],
    ],
    [
        'Gene Dependency (Achilles)',
        gct.read_gct('../data/achilles__gene_x_ccle_cellline.gct'),
        'low',
        'continuous',
        '../results/match_{}_and_Gene Dependency (Achilles).match.txt'.format(
            component),
        [
            'KRAS',
            'CTNNB1',
        ],
        [
            'KRAS',
            'CTNNB1',
        ],
    ],
]

# Make match summary panel
match_panel.make_summary_match_panel(
    target,
    features,
    title='Selected Features for {}'.format(target.name),
    file_path='../results/{}.summary_match_panel.pdf'.format(target.name))

# %%
# Select component
component = 'C6'
target = h_matrix.loc[component, :]
target.name = 'KRAS Component {}'.format(component)

# Select features
features = [
    [
        'Mutation',
        gct.read_gct('../data/mutation__gene_x_ccle_cellline.gct'),
        'high',
        'binary',
        '../results/match_{}_and_Mutation.match.txt'.format(component),
        [
            'BRAF.V600E_MUT',
        ],
        [
            'BRAF V600E',
        ],
    ],
    [
        'Gene Set',
        gct.read_gct('../data/gene_set__gene_set_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Gene Set.match.txt'.format(component),
        [
            'BRAF_UP',
            'ETV1_UP',
        ],
        [
            'BRAF Oncogenic Signature',
            'ETV1 Oncogenic Signature',
        ],
    ],
    [
        'Drug Sensitivity (CTD^2)',
        gct.read_gct('../data/ctd2__compound_x_ccle_cellline.gct'),
        'low',
        'continuous',
        '../results/match_{}_and_Drug Sensitivity (CTD^2).match.txt'.format(
            component),
        [
            'PLX-4720',
            'selumetinib',
            'PD318088',
        ],
        [
            'PLX4720 (BRAF Inhibitor)',
            'Selumetinib (MEK1 and MEK2 Inhibitor)',
            'PD318088 (MEK1 and MEK2 Inhibitor)',
        ],
    ],
]

# Make match summary panel
match_panel.make_summary_match_panel(
    target,
    features,
    title='Selected Features for {}'.format(target.name),
    file_path='../results/{}.summary_match_panel.pdf'.format(target.name))

# %%
# Select component
component = 'C7'
target = h_matrix.loc[component, :]
target.name = 'KRAS Component {}'.format(component)

# Select features
features = [
    [
        'Gene Expression',
        gct.read_gct('../data/rpkm__gene_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Gene Expression.match.txt'.format(component),
        [
            'FOSL1',
        ],
        [
            'FOSL1',
        ],
    ],
    [
        'Gene Set',
        gct.read_gct('../data/gene_set__gene_set_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Gene Set.match.txt'.format(component),
        [
            'HINATA_NFKB_TARGETS_FIBROBLAST_UP',
        ],
        [
            'Genes Up-Regulated by p50 and p65',
        ],
    ],
    [
        'Regulator Gene Set',
        gct.read_gct('../data/regulator__gene_set_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Regulator Gene Set.match.txt'.format(
            component),
        [
            'GGGNNTTTCC_V$NFKB_Q6_01',
            'V$AP1_Q4',
        ],
        [
            'NFKB Transcription Factor Targets',
            'AP1 Transcription Factor Targets',
        ],
    ],
    [
        'Protein Expression',
        gct.read_gct('../data/rppa__protein_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Protein Expression.match.txt'.format(
            component),
        [
            'NF-kB-p65_pS536-R-C',
            'FRA1_pS265-R-E',
        ],
        [
            'NFKB p65 pS536',
            'FRA1 pS265',
        ],
    ],
]

# Make match summary panel
match_panel.make_summary_match_panel(
    target,
    features,
    title='Selected Features for {}'.format(target.name),
    file_path='../results/{}.summary_match_panel.pdf'.format(target.name))

# %%
# Select component
component = 'C4'
target = h_matrix.loc[component, :]
target.name = 'KRAS Component {}'.format(component)

# Select features
features = [
    [
        'Gene Set',
        gct.read_gct('../data/gene_set__gene_set_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Gene Set.match.txt'.format(component),
        [
            'TAUBE_EMT_UP',
            'GROGER_EMT_UP',
        ],
        [
            'EMT Inducing Transcription Factors',
            'EMT Gene Set',
        ],
    ],
    [
        'Regulator Gene Set',
        gct.read_gct('../data/regulator__gene_set_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Regulator Gene Set.match.txt'.format(
            component),
        [
            'V$AREB6_03',
            'IPA_ZEB1',
        ],
        [
            'Targets of TCF8',
            'Targets of ZEB1',
        ],
    ],
    [
        'Protein Expresson',
        gct.read_gct('../data/rppa__protein_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Protein Expression.match.txt'.format(
            component),
        [
            'N-Cadherin-R-V',
            'E-Cadherin-R-V',
        ],
        [
            'N-Cadherin',
            'E-Cadherin',
        ],
    ],
]

# Make match summary panel
match_panel.make_summary_match_panel(
    target,
    features,
    title='Selected Features for {}'.format(target.name),
    file_path='../results/{}.summary_match_panel.pdf'.format(target.name))

# %%
# Select component
component = 'C2'
target = h_matrix.loc[component, :]
target.name = 'KRAS Component {}'.format(component)

# Select features
features = [
    [
        'Regulator Gene Set',
        gct.read_gct('../data/regulator__gene_set_x_ccle_cellline.gct'),
        'high', 'continuous',
        '../results/match_{}_and_Regulator Gene Set.match.txt'.format(
            component), [
                'V$E2F_02',
                'V$MAX_01',
                'V$MYCMAX_01',
                'IPA_MYC',
            ], [
                'Targets of E2F',
                'Targets of MAX',
                'Targets of MYC and MAX',
                'Targets of MYC',
            ]
    ],
]

# Make match summary panel
match_panel.make_summary_match_panel(
    target,
    features,
    title='Selected Features for {}'.format(target.name),
    file_path='../results/{}.summary_match_panel.pdf'.format(target.name))

# %%
# Select component
component = 'C5'
target = h_matrix.loc[component, :]
target.name = 'KRAS Component {}'.format(component)

# Select features
features = [
    [
        'Gene Expression',
        gct.read_gct('../data/rpkm__gene_x_ccle_cellline.gct'),
        'high',
        'continuous',
        '../results/match_{}_and_Gene Expression.match.txt'.format(component),
        [
            'PAX8',
            'HNF1B',
        ],
        [
            'PAX8',
            'HNF1B',
        ],
    ],
    [
        'Gene Dependency (Achilles)',
        gct.read_gct('../data/achilles__gene_x_ccle_cellline.gct'),
        'low',
        'continuous',
        '../results/match_{}_and_Gene Dependency (Achilles).match.txt'.format(
            component),
        [
            'PAX8',
            'HNF1B',
        ],
        [
            'PAX8',
            'HNF1B',
        ],
    ],
]

# Make match summary panel
match_panel.make_summary_match_panel(
    target,
    features,
    title='Selected Features for {}'.format(target.name),
    file_path='../results/{}.summary_match_panel.pdf'.format(target.name))
