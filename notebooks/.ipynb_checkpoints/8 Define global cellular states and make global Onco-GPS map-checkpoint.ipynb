# %%
from notebook_environment import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# Added '../tools/' to the path.

# %%
h_matrix = pd.read_table('../results/nmfcc/nmf_k9_h.txt', index_col=0)

h_matrix
# Out:
#      A101D_SKIN  A172_CENTRAL_NERVOUS_SYSTEM  A204_SOFT_TISSUE   A2058_SKIN  \
# C1    87.390561                    93.350830        393.899758   255.625865
# C3   518.647456                     7.308027        199.238501   176.804193
# C9    11.208338                   622.861218        717.757144     3.069694
# C8   239.003422                   479.108337        693.482964   478.286114
# C6  7166.174137                  1208.779409       1774.414891  6276.135642
# C7  1016.009451                  1672.966975        433.423134   955.066087
# C5   764.479691                   725.646766        517.555359   459.776995
# C2    64.829650                  1569.836315       3713.903057  1189.301135
# C4  1048.429865                  3514.982837       1599.533720   949.324498
#
#     A2780_OVARY    A375_SKIN  A498_KIDNEY     A549_LUNG    A673_BONE  \
# C1    12.230046   125.904286    15.489376  5.201425e-08     0.163371
# C3   545.601644   391.325939   452.722609  8.167350e+02   444.891880
# C9   446.187704     0.000439   740.861040  6.040093e+02   975.677929
# C8  1696.595193   503.049222   269.120017  6.510322e+02  2021.718516
# C6  1362.720325  4779.659070   838.082289  8.212941e-03  1611.742127
# C7     0.003192  1688.565623   961.965537  1.294276e+03    45.169949
# C5     0.000010     0.112397  4271.867752  3.473658e+03    23.952947
# C2  4612.165638  1692.563251  1041.812928  2.293922e+03  2825.029588
# C4  1395.774975  1317.373754  1505.001742  8.602564e+02  2186.326459
#
#     A704_KIDNEY      ...          WM88_SKIN  WM983B_SKIN  YAPC_PANCREAS  \
# C1     0.001205      ...         415.948914   305.351132    2248.563800
# C3  1664.636732      ...         295.629218   559.708338    2155.739326
# C9     1.341833      ...         463.865834   118.997647    1890.725829
# C8   372.320844      ...         363.270689   482.473882      14.761625
# C6  1417.850903      ...        7112.681988  7116.940554     543.418521
# C7    28.547109      ...         156.910209   617.164602    2113.148083
# C5  5576.769071      ...         952.997119   568.321975     719.250074
# C2   777.419387      ...         737.636509   493.994389     220.968519
# C4   488.753903      ...         427.337725   656.160837       0.500336
#
#     YD10B_UPPER_AERODIGESTIVE_TRACT  YD38_UPPER_AERODIGESTIVE_TRACT  \
# C1                       685.682262                     1798.525914
# C3                       355.439796                      302.706434
# C9                      5669.601718                     3901.938851
# C8                       512.785549                      401.354229
# C6                       209.558478                      493.361221
# C7                      1606.060845                     2266.279767
# C5                         2.775659                      541.816602
# C2                       436.847693                      112.120030
# C4                       580.722452                      129.765634
#
#     YD8_UPPER_AERODIGESTIVE_TRACT  YH13_CENTRAL_NERVOUS_SYSTEM  \
# C1                     104.278153                   199.214356
# C3                       0.000576                   328.560693
# C9                    3309.332406                   600.933737
# C8                      23.818909                   445.879251
# C6                      24.717198                  1032.356299
# C7                    1820.623602                  1502.274660
# C5                    1600.013238                   509.370896
# C2                     474.166240                   277.577697
# C4                    2539.073702                  4918.553670
#
#     YKG1_CENTRAL_NERVOUS_SYSTEM  ZR751_BREAST  ZR7530_BREAST
# C1                 3.819411e-01   4721.947367    4957.456757
# C3                 1.112408e+02    357.322949     653.472173
# C9                 1.969634e-10    457.725732     272.206384
# C8                 9.487706e+02    942.540098     814.310434
# C6                 2.382286e+03    285.983913     146.797171
# C7                 1.324849e+03      0.016081       0.001204
# C5                 2.454880e+02    505.321577     310.379079
# C2                 1.885415e+03   1270.077326    1061.667687
# C4                 3.186260e+03    940.169658    1203.297652
#
# [9 rows x 750 columns]

# %%
ccal.plot_heatmap(
    h_matrix,
    normalization_method='-0-',
    normalization_axis=1,
    cluster=True,
    xlabel='Sample',
    ylabel='KRAS Component',
    xticklabels=False)
# Out:
# /home/k/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
ds, hcs, cs, cccs = ccal.define_states(
    h_matrix,
    range(5, 17),
    n_clusterings=30,
    random_seed=830574,
    std_max=3,
    directory_path='../results/global')
# Out:
# Computing distances with <function compute_information_distance at 0x7fb30f24e950> ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (1/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (11/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (21/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (31/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (41/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (51/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (61/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (71/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (81/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (91/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (101/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (111/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (121/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (131/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (141/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (151/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (161/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (171/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (181/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (191/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (201/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (211/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (221/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (231/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (241/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (251/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (261/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (271/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (281/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (291/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (301/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (311/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (321/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (331/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (341/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (351/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (361/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (371/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (381/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (391/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (401/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (411/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (421/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (431/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (441/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (451/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (461/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (471/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (481/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (491/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (501/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (511/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (521/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (531/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (541/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (551/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (561/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (571/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (581/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (591/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (601/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (611/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (621/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (631/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (641/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (651/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (661/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (671/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (681/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (691/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (701/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (711/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (721/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (731/750) ...
# Applying <function compute_information_distance at 0x7fb30f24e950> (741/750) ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-959e2d086c4f> in <module>()
#       5     random_seed=830574,
#       6     std_max=3,
# ----> 7     directory_path='../results/global')
#
# ~/Jumis/onco_gps_paper_analysis/tools/ccal/ccal/onco_gps/onco_gps/define_states.py in define_states(df, ks, directory_path, distances, n_jobs, std_max, n_clusterings, random_seed)
#      40         n_clusterings=n_clusterings,
#      41         random_seed=random_seed,
# ---> 42         directory_path=directory_path)
#      43
#      44     return ds, hcs, cs, cccs
#
# ~/Jumis/onco_gps_paper_analysis/tools/ccal/ccal/onco_gps/onco_gps/cluster/cluster/hierarchical_consensus_cluster_with_multiple_ks.py in hierarchical_consensus_cluster_with_multiple_ks(df, ks, distances, distance_function, n_jobs, n_clusterings, random_seed, directory_path)
#      57
#      58         if directory_path:
# ---> 59             distances.to_csv(join(directory_path, 'distances.txt'), sep='\t')
#      60
#      61             plot_clustermap(
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/pandas/io/formats/format.py in save(self)
#    1575             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1576                                      encoding=self.encoding,
# -> 1577                                      compression=self.compression)
#    1578             close = True
#    1579
#
# ~/Jumis/tools/anaconda/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     383         elif is_text:
#     384             # Python 3 and no explicit encoding
# --> 385             f = open(path_or_buf, mode, errors='replace')
#     386         else:
#     387             # Python 3 and binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/global/distances.txt'

# %%
cs = pd.read_table(
    '../results/global/hcc/hccs.txt', index_col=0)

# %%
sample_states = cs.loc['K15', :]

# %%
component_names = [
    'C1 ERBB3/PI3K', 'C3 RAS/WNT/PI3K', 'C9 KRAS/AP1', 'C8 MYC',
    'C6 BRAF/MAPK', 'C7 TNF/NFkB', 'C5 HNF1/PAX8', 'C2 MYC/E2F', 'C4 EMT',
]

# %%
colors = [
    '#993300',
    '#FFD700',
    '#E74C3C',
    '#8B008B',
    '#B0E0E6',
    '#4169E1',
    '#DC143C',
    '#669999',
    '#F4BD60',
    '#2E8B57',
    '#4b0082',
    '#D2691E',
    '#FA8072',
    '#DA70D6',
    '#90EE90',
]

# %%
ccal.plot_heatmap(
    h_matrix,
    normalization_method='-0-',
    normalization_axis=1,
    data_type='continuous',
    annotation_colors=colors,
    column_annotation=sample_states,
    title='H-Matrix Clustering by State',
    xlabel='Sample',
    ylabel='Component',
    xticklabels=False)

# %%
ccal.oncogps.make_oncogps(
    training_h=h_matrix,
    training_states=global_sample_labels,
    title='Global Onco-GPS Map',
    power=2.5,
    component_markersize=24,
    component_fontsize=22,
    component_markerfacecolor='#000080',
    sample_markersize=18,
    mds_seed=1234,
    std_max=2,
    state_colors=colors,
    kde_bandwidth_factor=1.25,
    informational_mds=False,
    component_names=component_names)

# %%
gps_map = ccal.GPSMap(
    h_matrix,
    pull_power=1.2,
    node_x_dimension=pd.DataFrame(
        [[0.5, np.sqrt(3) / 2], [1, 0], [0, 0]],
        index=h_matrix.index))

# %%
gps_map.set_sample_phenotypes(
    sample_states,
    phenotype_type='categorical',
    bandwidth_factor=2.8,
    phenotype_color_map=mpl.colors.ListedColormap(colors),
    phenotype_to_str={i: 'State {}'.format(i + 1)
                      for i in range(15)})

gps_map.plot_samples_with_phenotype()

# %%
gps_map.save('../results/global_gps_map.pickle.gz')
